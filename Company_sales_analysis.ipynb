# %%
import pandas as pd
import matplotlib
df = pd.read_csv("company_sales_data.csv")
plt.plot(df['month_number'], df['total_profit'], marker='o', linestyle='-', color='blue')
plt.xlabel("Month")
plt.ylabel("Total Profit of all months")
plt.title("Line Chart")
plt.grid()
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(df['month_number'], df['bathingsoap'], marker='o', linestyle='-', color='blue')
plt.xlabel("Month")
plt.ylabel("Bathing Soap")
plt.title("Line Chart")
plt.grid()

plt.subplot(1,2,2)
plt.plot(df['month_number'], df['facewash'], marker='o', linestyle='-', color='blue')
plt.xlabel("Month")
plt.ylabel("Face Wash")
plt.title("Line Chart")
plt.grid()


plt.show()
